# %%
import json
import rppglib.train

# %%
class config:
    fps = 30
    ppg_low_freq = 0.5
    ppg_high_freq = 10
    batch_size = 36
    num_workers = 36
    train_dataset = 'mcd_rppg'
    test_datasets = ['mcd_rppg', 'MMPD', 'SCAMPS', 'UBFC_rPPG']
    num_folds = 5
    test_fold = 0
    valid_fold = 1
    model = 'SCNN_8rois'
    results_folder = 'results'
    device = 'cuda:0'

# %%
for valid_fold in range(1, config.num_folds):
    config.valid_fold = valid_fold
    config = rppglib.train.train_fold(config)
    cfg = {k:v for k, v in config.__dict__.items() if not k.startswith('__')}
    name = f'{config.results_folder}/{config.model}__{config.train_dataset}__{config.valid_fold}'
    with open(f'{name}.cfg', 'w') as fp:
        json.dump(cfg, fp)
# Out:
# Model SCNN_8rois loaded
# Training on fold 1
# Train files: 720
# Valid files: 240
# Training epochs: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [08:20<00:00, 10.02s/it]
# Training process:
# Testing on mcd_rppg
# Test files: 240
# Testing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:20<00:00,  2.89s/it]
# Testing true PPGs: (240, 600)
# Testing pred PPGs: (240, 600)
# Mean true HRs: 83.291015625
# Mean pred HRs: 82.939453125
# PPG MAE: 0.5555557012557983
# HR MAE: 4.3212890625
#
# Testing on MMPD
# Test files: 114
# Testing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:26<00:00,  6.65s/it]
# Testing true PPGs: (114, 600)
# Testing pred PPGs: (114, 600)
# Mean true HRs: 83.28022203947368
# Mean pred HRs: 81.58408717105263
# PPG MAE: 0.9841330647468567
# HR MAE: 17.547286184210527
#
# Testing on SCAMPS
# Test files: 554
# Testing: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:26<00:00,  1.65s/it]
# Testing true PPGs: (554, 600)
# Testing pred PPGs: (554, 600)
# Mean true HRs: 97.09851647111914
# Mean pred HRs: 83.28985221119133
# PPG MAE: 0.9447658061981201
# HR MAE: 24.463419449458485
#
# Testing on UBFC_rPPG
# Test files: 9
# Testing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:07<00:00,  7.20s/it]
# Testing true PPGs: (9, 600)
# Testing pred PPGs: (9, 600)
# Mean true HRs: 97.65625
# Mean pred HRs: 95.703125
# PPG MAE: 1.0208978652954102
# HR MAE: 3.515625
# Model SCNN_8rois loaded
# Training on fold 2
# Train files: 720
# Valid files: 240
# Training epochs: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [07:57<00:00,  9.56s/it]
# Training process:
# Testing on mcd_rppg
# Test files: 240
# Testing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.35it/s]
# Testing true PPGs: (240, 600)
# Testing pred PPGs: (240, 600)
# Mean true HRs: 83.291015625
# Mean pred HRs: 83.76708984375
# PPG MAE: 0.6046237945556641
# HR MAE: 4.85595703125
#
# Testing on MMPD
# Test files: 114
# Testing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:07<00:00,  1.88s/it]
# Testing true PPGs: (114, 600)
# Testing pred PPGs: (114, 600)
# Mean true HRs: 83.28022203947368
# Mean pred HRs: 85.13055098684211
# PPG MAE: 0.9318630695343018
# HR MAE: 19.42845394736842
#
# Testing on SCAMPS
# Test files: 554
# Testing: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:08<00:00,  1.97it/s]
# Testing true PPGs: (554, 600)
# Testing pred PPGs: (554, 600)
# Mean true HRs: 97.09851647111914
# Mean pred HRs: 82.6044957129964
# PPG MAE: 0.9655680060386658
# HR MAE: 25.656447427797833
#
# Testing on UBFC_rPPG
# Test files: 9
# Testing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.56s/it]
# Testing true PPGs: (9, 600)
# Testing pred PPGs: (9, 600)
# Mean true HRs: 97.65625
# Mean pred HRs: 78.90625
# PPG MAE: 0.9338301420211792
# HR MAE: 19.53125
# Model SCNN_8rois loaded
# Training on fold 3
# Train files: 720
# Valid files: 240
# Training epochs: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [07:42<00:00,  9.25s/it]
# Training process:
# Testing on mcd_rppg
# Test files: 240
# Testing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.33it/s]
# Testing true PPGs: (240, 600)
# Testing pred PPGs: (240, 600)
# Mean true HRs: 83.291015625
# Mean pred HRs: 83.59130859375
# PPG MAE: 0.6114839911460876
# HR MAE: 5.03173828125
#
# Testing on MMPD
# Test files: 114
# Testing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:07<00:00,  1.98s/it]
# Testing true PPGs: (114, 600)
# Testing pred PPGs: (114, 600)
# Mean true HRs: 83.28022203947368
# Mean pred HRs: 82.9564144736842
# PPG MAE: 0.9137446284294128
# HR MAE: 16.483347039473685
#
# Testing on SCAMPS
# Test files: 554
# Testing: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:07<00:00,  2.05it/s]
# Testing true PPGs: (554, 600)
# Testing pred PPGs: (554, 600)
# Mean true HRs: 97.09851647111914
# Mean pred HRs: 83.89588504061372
# PPG MAE: 1.0011879205703735
# HR MAE: 22.70243400270758
#
# Testing on UBFC_rPPG
# Test files: 9
# Testing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.61s/it]
# Testing true PPGs: (9, 600)
# Testing pred PPGs: (9, 600)
# Mean true HRs: 97.65625
# Mean pred HRs: 96.875
# PPG MAE: 0.9832812547683716
# HR MAE: 2.34375
# Model SCNN_8rois loaded
# Training on fold 4
# Train files: 720
# Valid files: 240
# Training epochs: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [07:55<00:00,  9.50s/it]
# Training process:
# Testing on mcd_rppg
# Test files: 240
# Testing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.33it/s]
# Testing true PPGs: (240, 600)
# Testing pred PPGs: (240, 600)
# Mean true HRs: 83.291015625
# Mean pred HRs: 83.59130859375
# PPG MAE: 0.5704889297485352
# HR MAE: 4.37255859375
#
# Testing on MMPD
# Test files: 114
# Testing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:07<00:00,  1.92s/it]
# Testing true PPGs: (114, 600)
# Testing pred PPGs: (114, 600)
# Mean true HRs: 83.28022203947368
# Mean pred HRs: 80.73601973684211
# PPG MAE: 0.9442798495292664
# HR MAE: 17.22347861842105
#
# Testing on SCAMPS
# Test files: 554
# Testing: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:07<00:00,  2.02it/s]
# Testing true PPGs: (554, 600)
# Testing pred PPGs: (554, 600)
# Mean true HRs: 97.09851647111914
# Mean pred HRs: 89.2867215703971
# PPG MAE: 0.9577912092208862
# HR MAE: 21.93775383574007
#
# Testing on UBFC_rPPG
# Test files: 9
# Testing: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.51s/it]
# Testing true PPGs: (9, 600)
# Testing pred PPGs: (9, 600)
# Mean true HRs: 97.65625
# Mean pred HRs: 83.3984375
# PPG MAE: 1.038185715675354
# HR MAE: 14.6484375

# %%
from glob import glob
import json
import numpy as np

def open_cfg(file):
    with open(file, 'rt') as f:
        data = json.loads(f.read())
    return data

cfgs = glob(f'results/{config.model}__{config.train_dataset}__*.cfg')
cfgs = [open_cfg(file) for file in cfgs]
print(len(cfgs))
# Out:
# 4

# %%
for ds in config.test_datasets:
    vals_ppg = [cfg['test_results'][f'test__{ds}__ppg'] for cfg in cfgs]
    vals_hr = [cfg['test_results'][f'test__{ds}__hr'] for cfg in cfgs]

    print()
    print(f'Test results on "{ds}" dataset:')
    print(f'HR  MAE: {np.mean(vals_hr):.2f}+/-{np.std(vals_hr):.3f}')
    print(f'PPG MAE: {np.mean(vals_ppg):.2f}+/-{np.std(vals_ppg):.3f}')
# Out:
# Test results on "mcd_rppg" dataset:
# HR  MAE: 4.65+/-0.305
# PPG MAE: 0.59+/-0.023
#
# Test results on "MMPD" dataset:
# HR  MAE: 17.67+/-1.086
# PPG MAE: 0.94+/-0.026
#
# Test results on "SCAMPS" dataset:
# HR  MAE: 23.69+/-1.459
# PPG MAE: 0.97+/-0.021
#
# Test results on "UBFC_rPPG" dataset:
# HR  MAE: 10.01+/-7.299
# PPG MAE: 0.99+/-0.040
